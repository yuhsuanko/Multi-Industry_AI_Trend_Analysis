# %% [markdown]
# # Entity extraction (people, organizations, technologies)

# %% [markdown]
# Load packages

# %%
import pandas as pd
from collections import Counter
from itertools import chain
import numpy as np
import ast

# %% [markdown]
# Connect to google drive

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load data

# %%
df = pd.read_parquet("/content/drive/MyDrive/Colab Notebooks/temp_data_md_entities.parquet", engine="pyarrow")

# %%
df.head()
# Out:
#    index                                                url       date  \
# 0      0            https://pjmedia.com/instapundit/494418/ 2022-01-01
# 1      1  https://www.vikatan.com/amp/story/automobile%2... 2022-01-01
# 2      2  https://www.equities.com/news/exchange-listed-... 2022-01-01
# 3      3  https://www.financialexpress.com/lifestyle/boo... 2022-01-01
# 4      4  https://www.newsbreak.com/news/2470570042311/5... 2022-01-01
#
#   language                                              title  \
# 0       en  Instapundit  » Blog Archive   » HMM:  An Advan...
# 1       en  Artificial Intelligence Reshaping the Automoti...
# 2       en  Exchange Listed Funds - QRAFT AI Enhanced U.S....
# 3       en  Book Review: The Age of AI and Our Human Futur...
# 4       en  5 Places to Start a Career in Data Science in ...
#
#                                                 text  \
# 0  \n\n\nInstapundit  » Blog Archive   » HMM:  An...
# 1  Artificial Intelligence Reshaping the Automoti...
# 2  \n\nExchange Listed Funds - QRAFT AI Enhanced ...
# 3  \n\nBook Review: The Age of AI and Our Human F...
# 4  5 Places to Start a Career in Data Science in ...
#
#                                clean_text_with_punct  \
# 0  Instapundit Blog Archive HMM: An Advanced AI G...
# 1  Artificial Intelligence Reshaping the Automoti...
# 2  Exchange Listed Funds - QRAFT AI Enhanced U.S....
# 3  Book Review: The Age of AI and Our Human Futur...
# 4    5 Places to Start a Career in Data Science in -
#
#                                           clean_text  topic_BERT  \
# 0  instapundit blog archive hmm advanced  give un...         247
# 1   reshape automotive industryx vikatan original...          20
# 2  exchange list fund qraft  enhance large cap et...          -1
# 3  book review age  human future henry kissinger ...          -1
# 4                   place start career datum science         492
#
#    topic_BERT_prob  Topic                                               Name  \
# 0         0.455750    247  247_instapundit_heather havrilesky_tcs daily_t...
# 1         0.599253     20  20_automotive industry_automotive_automaker_el...
# 2         0.000000     -1                -1_tech_industry_technology_feature
# 3         0.000000     -1                -1_tech_industry_technology_feature
# 4         1.000000    492  492_india magazine_analytic india_datum scient...
#
#   Predicted_Industry                                     named_entities
# 0         Technology  {'LOCATION': ['NEW YORK CITY', 'New Y', 'Iraq'...
# 1              Sport  {'LOCATION': [], 'ORG': ['Vikatan Originals'],...
# 2         Technology  {'LOCATION': ['US', 'China', 'Xinjiang'], 'ORG...
# 3         Technology  {'LOCATION': ['India', 'US', 'India', 'US', 'U...
# 4         Technology  {'LOCATION': [], 'ORG': [], 'PERSON': [], 'TEC...

# %%
df.loc[0,'named_entities']
# Out:
# {'LOCATION': array(['NEW YORK CITY', 'New Y', 'Iraq', 'Mudville Gazette', 'N.Z.',
#         'California', 'California', 'U.S.'], dtype=object),
#  'ORG': array(['InstaPundit', 'the Amazon Services LLC Associates Program',
#         'Amazon', 'Instapundit Archives', 'Cliopatria Deceiver.com',
#         'The Tatler WiFi', 'ALDaily', 'PoliticalWire', 'RealClearPolitics',
#         'TCS', 'The Note', 'RealClearPolitics', 'SCSU', 'WordPress',
#         'Reg.'], dtype=object),
#  'PERSON': array(['ERIC ADAMS', 'Eric Adams', 'Glenn Reynolds',
#         'Andrew Malcolm Barone', 'Bluey', 'Chris Anderson Cox', 'Forkum',
#         'Dan Gillmor', 'Dave Barry', 'David Corn', 'David Frum',
#         'Don Surber', 'Ernie the', 'Flit Fraters', 'Libertas',
#         'Gary Farber', 'Howard Kurtz', 'Hugh Hewitt', 'Jennifer Rubin',
#         'Jim Geraghty', 'Josh Marshall', 'Jules Crittenden',
#         'JWR Kausfiles', 'Kevin Drum', 'Larry Kudlow', 'Mark Steyn',
#         'Martin Peretz', 'Michael Silence', 'Michelle Malkin',
#         'Neal Boortz', 'Rich Galen', 'Scott Rosenberg', 'Virginia Postrel',
#         'Walter Shapiro', 'Alphecca', 'Andrea', 'Andrew Olmsted',
#         'Ann Althouse', 'Baldilocks', 'Bill Peschel', 'Bill Quick',
#         'Bill Whittle', 'Bjorn Staerk Blackfive', 'Brad DeLong',
#         'Brian Carnell', 'Brian Linse', 'Judd Burchismo',
#         'Ed Charles Austin', 'Charles Murtaugh', 'Clayton Cramer',
#         'Colby Cosh', 'Cori Dauber', 'Damian Penny', 'Daniel Drezner',
#         'Dave Kopel', 'Dave Winer', 'David Pinto',
#         'Dean Esmay Deinonychus', 'Denise Howell', 'Derek Lowe',
#         'Diana Hsieh', 'Donald Luskin', 'Donald Sensing', 'Frank',
#         'Ed Cone', 'Ed Driscoll', 'Edward Boyd', 'Eric Muller', 'Eric S.',
#         'Raymond Eve Tushnet', 'Heather Havrilesky', 'Howard Bashman',
#         'Howard Owens', 'Howard Veit', 'Jack Balkin', 'James Lileks',
#         'Jason Kottke', 'Jay Manifold', 'Jeff Goldstein', 'Jeff Jarvis',
#         'Jerry Pournelle', 'Jessica s', 'Jim Henley', 'Jim Miller',
#         'Jim Treacher', 'Joanne Jacobs', 'John Cole', 'John Ellis',
#         'John Scalzi', 'John Weidner', 'Joshua Claybourn',
#         'Kate Kathy Kinsley', 'Katie Granju', 'Kesher', 'Kevin Holtsberry',
#         'La Shawn Barber', 'Larry Lessig', 'Laurence Simon',
#         'Missy Lynne Kiesling', 'Mark Byron Martin', 'Devon', 'Matt Welch',
#         'Matthew Hoy', 'Megan McArdle', 'Meryl Yourish', 'Michael Totten',
#         'Mike Silverman', 'Milt Rosenberg', 'Mitch Berg', 'Moira Breen',
#         'Bear NanoDot', 'Natalie Solent', 'Nick Denton', 'Rand Simberg',
#         'Rantburg', 'Rebecca Blood', 'Reid Stott', 'Rich Hailey',
#         'Robert Musil', 'Robin Roberts', 'Roger L.', 'Simon Samizdata',
#         'Sissy Willis', 'Stefan Sharkansky', 'Stephen Green',
#         'Steven Den Beste', 'Stuart Buck', 'The Fat Guy', 'The Volokh',
#         'Tim Blair', 'Walter Olson', 'Will Warren', 'William Hobbs',
#         'Zion Zeyad'], dtype=object),
#  'TECH': array([], dtype=object)}

# %% [markdown]
# Normalize entity list

# %%
def normalize_entity_list(entity_list):
    if isinstance(entity_list, str):
        try:
            entity_list = ast.literal_eval(entity_list)
        except Exception:
            return []

    # Accept both list and np.ndarray
    if isinstance(entity_list, (list, np.ndarray)):
        return [ent.strip().lower().title() for ent in entity_list if isinstance(ent, str) and ent.strip()]

    return []

# %%
# Normalize named entities
df['normalized_entities'] = df['named_entities'].apply(lambda ents: {
    k: normalize_entity_list(v) for k, v in ents.items()
})

# %%
df.head()
# Out:
#    index                                                url       date  \
# 0      0            https://pjmedia.com/instapundit/494418/ 2022-01-01
# 1      1  https://www.vikatan.com/amp/story/automobile%2... 2022-01-01
# 2      2  https://www.equities.com/news/exchange-listed-... 2022-01-01
# 3      3  https://www.financialexpress.com/lifestyle/boo... 2022-01-01
# 4      4  https://www.newsbreak.com/news/2470570042311/5... 2022-01-01
#
#   language                                              title  \
# 0       en  Instapundit  » Blog Archive   » HMM:  An Advan...
# 1       en  Artificial Intelligence Reshaping the Automoti...
# 2       en  Exchange Listed Funds - QRAFT AI Enhanced U.S....
# 3       en  Book Review: The Age of AI and Our Human Futur...
# 4       en  5 Places to Start a Career in Data Science in ...
#
#                                                 text  \
# 0  \n\n\nInstapundit  » Blog Archive   » HMM:  An...
# 1  Artificial Intelligence Reshaping the Automoti...
# 2  \n\nExchange Listed Funds - QRAFT AI Enhanced ...
# 3  \n\nBook Review: The Age of AI and Our Human F...
# 4  5 Places to Start a Career in Data Science in ...
#
#                                clean_text_with_punct  \
# 0  Instapundit Blog Archive HMM: An Advanced AI G...
# 1  Artificial Intelligence Reshaping the Automoti...
# 2  Exchange Listed Funds - QRAFT AI Enhanced U.S....
# 3  Book Review: The Age of AI and Our Human Futur...
# 4    5 Places to Start a Career in Data Science in -
#
#                                           clean_text  topic_BERT  \
# 0  instapundit blog archive hmm advanced  give un...         247
# 1   reshape automotive industryx vikatan original...          20
# 2  exchange list fund qraft  enhance large cap et...          -1
# 3  book review age  human future henry kissinger ...          -1
# 4                   place start career datum science         492
#
#    topic_BERT_prob  Topic                                               Name  \
# 0         0.455750    247  247_instapundit_heather havrilesky_tcs daily_t...
# 1         0.599253     20  20_automotive industry_automotive_automaker_el...
# 2         0.000000     -1                -1_tech_industry_technology_feature
# 3         0.000000     -1                -1_tech_industry_technology_feature
# 4         1.000000    492  492_india magazine_analytic india_datum scient...
#
#   Predicted_Industry                                     named_entities  \
# 0         Technology  {'LOCATION': ['NEW YORK CITY', 'New Y', 'Iraq'...
# 1              Sport  {'LOCATION': [], 'ORG': ['Vikatan Originals'],...
# 2         Technology  {'LOCATION': ['US', 'China', 'Xinjiang'], 'ORG...
# 3         Technology  {'LOCATION': ['India', 'US', 'India', 'US', 'U...
# 4         Technology  {'LOCATION': [], 'ORG': [], 'PERSON': [], 'TEC...
#
#                                  normalized_entities
# 0  {'LOCATION': ['New York City', 'New Y', 'Iraq'...
# 1  {'LOCATION': [], 'ORG': ['Vikatan Originals'],...
# 2  {'LOCATION': ['Us', 'China', 'Xinjiang'], 'ORG...
# 3  {'LOCATION': ['India', 'Us', 'India', 'Us', 'U...
# 4  {'LOCATION': [], 'ORG': [], 'PERSON': [], 'TEC...

# %% [markdown]
# Extract and count organizations, people, technology, and locations

# %%
orgs = Counter(chain.from_iterable(df['normalized_entities'].dropna().apply(lambda x: x['ORG'])))
people = Counter(chain.from_iterable(df['normalized_entities'].dropna().apply(lambda x: x['PERSON'])))
techs = Counter(chain.from_iterable(df['normalized_entities'].dropna().apply(lambda x: x['TECH'])))
locations = Counter(chain.from_iterable(df['normalized_entities'].dropna().apply(lambda x: x['LOCATION'])))

# %%
# Show top 100 results
print("\nTop Organizations:\n", orgs.most_common(100))
print("\nTop People:\n", people.most_common(100))
print("\nTop Technologies:\n", techs.most_common(100))
print("\nTop Locations:\n", locations.most_common(100))
# Out:
# Top Organizations:
#  [('Openai', 164609), ('Google', 163236), ('Microsoft', 132160), ('Apple', 80942), ('Nvidia', 66114), ('Chatgpt', 57172), ('Amazon', 52961), ('Lg', 46763), ('Fcc', 40113), ('Meta', 38344), ('Facebook', 36808), ('Samsung', 35254), ('Youtube', 33292), ('Linkedin', 28920), ('Twitter', 22338), ('Digi Communications N.V.', 20767), ('Nasdaq', 19840), ('Ap', 18394), ('Intel', 17799), ('Instagram', 17206), ('Amd', 17030), ('Eu', 16932), ('Tesla', 16597), ('Ibm', 15404), ('Tiktok', 14682), ('Bing', 13649), ('The Associated Press', 13276), ('Netflix', 13100), ('Associated Press', 13097), ('Menafn', 12726), ('Congress', 12685), ('Anthropic', 11958), ('Ein', 11634), ('Google Play', 11428), ('Aws', 11393), ('Alphabet', 11010), ('Cnbc', 10542), ('Adobe', 9699), ('Getty Images', 9673), ('Fda', 9449), ('Nexstar', 8998), ('Nexstar Media Inc.', 8638), ('Nfl', 8620), ('Newsfeed', 8497), ('Reddit', 8453), ('Cna', 8136), ('Mint', 8057), ('Whatsapp', 7971), ('Deepseek', 7853), ('The Motley Fool', 7672), ('Bloomberg', 7669), ('Afp', 7582), ('Sony', 7281), ('Android', 7085), ('Salesforce', 6878), ('Dell', 6397), ('Sec', 6304), ('Fox', 6262), ('Oracle', 6245), ('Lenovo', 5883), ('Baidu', 5850), ('Cision', 5832), ('Pbs', 5813), ('Senate', 5798), ('Ftc', 5776), ('Huawei', 5762), ('White House', 5675), ('Nasdaq.Com', 5637), ('Spotify', 5630), ('Nasa', 5542), ('Qualcomm', 5420), ('Un', 5416), ('Fed', 5233), ('Ein Presswire', 5226), ('Bard', 5146), ('Forbes', 5142), ('Nbc', 5142), ('Newsnation', 5118), ('Nba', 5079), ('Digi Communications Nv', 4978), ('Zdnet', 4959), ('Google Cloud', 4951), ('Snapchat', 4907), ('Oneplus', 4893), ('Sap', 4731), ('X', 4712), ('Cbs', 4706), ('Asus', 4659), ('The New York Times', 4598), ('House', 4591), ('Future', 4584), ('Windows', 4571), ('Walmart', 4567), ('Oppo', 4529), ('Daily Mail', 4507), ('Disney', 4494), ('Xiaomi', 4493), ('Nasdaq, Inc.', 4443), ('The White House', 4438), ('Bt', 4322)]
#
# Top People:
#  [('Trump', 29713), ('Biden', 23695), ('Altman', 21742), ('Sam Altman', 21191), ('Musk', 20552), ('Elon Musk', 20006), ('Donald Trump', 8649), ('Taylor Swift', 8504), ('Modi', 6908), ('Joe Biden', 6807), ('Putin', 4420), ('Bobby Allyn', 3960), ('Satya Nadella', 3861), ('Mark Zuckerberg', 3538), ('Kim Kardashian', 3518), ('Sundar Pichai', 3362), ('Bard', 3353), ('Charles', 3281), ('Harris', 3280), ('Narendra Modi', 3142), ('Kamala Harris', 3086), ('Sunak', 2983), ('Rishi Sunak', 2823), ('Harry', 2822), ("Matt O'Brien", 2811), ('Meghan', 2809), ('Zuckerberg', 2809), ('Travis Kelce', 2701), ('Bill Gates', 2645), ('Prince Harry', 2630), ('David', 2612), ("Elon Musk'S", 2468), ('Metla Sudha Sekhar', 2450), ('Jensen Huang', 2440), ('Nadella', 2434), ('Jennifer Lopez', 2410), ('Kate', 2384), ('Elon Musk S', 2371), ('Huang', 2292), ('Drake', 2275), ('Schumer', 2197), ('Pichai', 2183), ('Phil Mackintosh', 2147), ('Barbie', 2124), ('Hinton', 2030), ('Scarlett Johansson', 2005), ('Meghan Markle', 1939), ('Greg Brockman', 1921), ('Desantis', 1908), ('Ben Affleck', 1897), ('Geoffrey Hinton', 1856), ('Kylie Jenner', 1847), ('Britney Spears', 1809), ('Buffett', 1795), ('Mccartney', 1735), ('Shakespeare', 1719), ('Warren Buffett', 1711), ('Xi', 1685), ('Johansson', 1672), ('Xi Jinping', 1640), ('My Quotes', 1628), ('Geoff Brumfiel', 1600), ('Mira Murati', 1598), ('Brockman', 1595), ('Paul Mccartney', 1545), ('Madonna', 1543), ('Netanyahu', 1538), ('Kim', 1514), ('Ilya Sutskever', 1513), ('Shear', 1478), ('Kanye West', 1469), ('Tim Cook', 1465), ('Smith', 1438), ('Khan', 1418), ('Diddy', 1410), ('Kelvin Chan', 1403), ('Selena Gomez', 1400), ('Tupac', 1396), ('Katy Perry', 1391), ('Rihanna', 1389), ('John', 1380), ('Shannon Bond', 1353), ("Taylor Swift'S", 1342), ('Lemoine', 1328), ('William', 1324), ('Tom Brady', 1316), ('Tom Cruise', 1307), ('Virat Kohli', 1287), ('Hailey Bieber', 1269), ('Emily Ratajkowski', 1262), ('Sam', 1260), ('John Larkin', 1260), ('Camilla', 1258), ('Francis', 1240), ('Sutskever', 1237), ('Kendall Jenner', 1222), ('Beyonce', 1222), ('King', 1212), ('Chuck Schumer', 1205), ('Victoria Beckham', 1201)]
#
# Top Technologies:
#  [('Chatgpt', 121133), ('Bard', 13270), ('Generative Ai', 4000), ('Openai', 3083), ('Chatgpt Plus', 2889), ('Ultragear', 2660), ('Meta Ai', 2448), ('Gpt-4', 2431), ('Galaxy Ai', 2111), ('Gmail', 1863), ('Gpt', 1689), ('Vision Pro', 1624), ('Llama 2', 1572), ('Metaverse', 1548), ('Llama', 1360), ('Safari', 1325), ('Chat Gpt', 1293), ('Airpods', 1277), ('Apple Vision Pro', 1258), ('Genai', 1159), ('Node Ai', 1043), ('Arbdoge Ai', 981), ('Search', 972), ('Gemini Ai', 958), ('Sleepless Ai', 919), ('Vertex Ai', 879), ('Quantum Ai', 861), ('Macbook Air', 837), ('Barchart', 819), ('Google Bard', 754), ('My Ai', 750), ('Thinq Ai', 750), ('Cybertruck', 726), ('Java', 726), ('Gpt-4 Turbo', 724), ('Stargate', 723), ('Chatgpt Enterprise', 689), ('Paal Ai', 663), ('Gptzero', 653), ('Gpt-3', 650), ('Google Cloud', 631), ('Palm Ai', 609), ('Llama 3', 592), ('Ipad Air', 587), ('Lunar Lake', 569), ('Searchgpt', 560), ('Arm', 552), ('Stability Ai', 548), ('Duet Ai', 519), ('Tech Radar Pro', 517), ('Ai Dd', 511), ('Smartwatch', 504), ('Xai', 481), ('Grok Ai', 481), ('Edge Ai', 475), ('Azure Openai Service', 452), ('Starlink', 442), ('Lightchain Ai', 437), ('Conversational Ai', 434), ('The Ai Pin', 434), ('Dolby Vision', 425), ('Ai', 421), ('Spark', 407), ('Soundbars', 406), ('Smart Tv', 400), ('Ai Pin', 397), ('Gpt4', 386), ('Webcatalog Desktoplearn', 376), ('Clickup Ai', 374), ('Starship', 369), ('Azure Openai', 361), ('Grammarly', 360), ('Copilot Ai', 353), ('Paint', 346), ('Truthgpt', 338), ('Aria', 337), ('Chatgpt Pro', 334), ('Artificial Intelligence', 333), ('Chatgpt 4', 332), ('Smart Home', 330), ('Mistral Ai', 318), ('Grok Chatbot', 317), ('Apache Spark', 316), ('Soundhound Ai', 314), ('Ai Sound Pro', 313), ('Transformer', 312), ('Circle To Search', 311), ('Gpt-4O', 311), ('Soundbar', 307), ('Gen Ai', 304), ('Chrome Safari', 302), ('Bard Ai', 300), ('Cardano', 299), ('The Vision Pro', 288), ('Airpods Pro', 287), ('Ai Studio', 286), ('Trainium', 285), ('Chatbot', 281), ('Smartsheetlearnblogsoftware', 273), ('Ai Thinq', 272)]
#
# Top Locations:
#  [('Us', 181028), ('India', 104947), ('U.S.', 90392), ('China', 71526), ('Uk', 51850), ('New York', 35563), ('Canada', 35509), ('Europe', 32864), ('California', 32612), ('Russia', 26779), ('United States', 26465), ('Ukraine', 26311), ('Australia', 25630), ('Israel', 25444), ('France', 23751), ('Uae', 23384), ('Texas', 22854), ('Japan', 22038), ('Washington', 21961), ('Florida', 21321), ('Germany', 20593), ('London', 18536), ('Italy', 18055), ('Singapore', 17860), ('Saudi Arabia', 17696), ('Pakistan', 17625), ('Middle East', 16969), ('Spain', 16429), ('Lebanon', 16205), ('Georgia', 16183), ('Colorado', 15095), ('San Francisco', 15067), ('Ohio', 14754), ('Egypt', 13644), ('Brazil', 13618), ('Delhi', 13429), ('Maine', 13265), ('Indonesia', 13244), ('Taiwan', 13235), ('Pennsylvania', 13181), ('Hollywood', 13171), ('Mexico', 13026), ('Michigan', 12931), ('Utah', 12887), ('Portugal', 12793), ('Oklahoma', 12678), ('Malaysia', 12579), ('United Kingdom', 12562), ('Asia', 12505), ('Wyoming', 12477), ('Kuwait', 12455), ('Connecticut', 12405), ('The United States', 12374), ('Iraq', 12349), ('Bahrain', 12261), ('New Mexico', 12102), ('Illinois', 11971), ('Syria', 11920), ('Oman', 11897), ('South Africa', 11675), ('Morocco', 11619), ('Arizona', 11452), ('Jordan', 11412), ('Arkansas', 11368), ('Idaho', 11366), ('Iowa', 11254), ('Hong Kong', 11213), ('Yemen', 11184), ('Tunisia', 11160), ('Minnesota', 11132), ('Algeria', 11076), ('New Zealand', 10915), ('North America', 10834), ('Missouri', 10833), ('Qatar', 10691), ('Indiana', 10667), ('Poland', 10663), ('Palestine', 10649), ('North Carolina', 10620), ('Massachusetts', 10568), ('Hawaii', 10536), ('Mumbai', 10516), ('Tennessee', 10450), ('Oregon', 10414), ('Los Angeles', 10382), ('New Jersey', 10370), ('Denmark', 10337), ('Wisconsin', 10235), ('Louisiana', 10080), ('America', 10042), ('South Korea', 9992), ('Montana', 9878), ('Kansas', 9806), ('New Hampshire', 9803), ('Alabama', 9719), ('Kenya', 9681), ('Delaware', 9664), ('Dubai', 9633), ('Virginia', 9589), ('Maryland', 9467)]

# %% [markdown]
# Group names

# %%
# Alias groups for consolidation
alias_groups = {
    'Elon Musk': ['Musk', 'Elon Musk', "Elon Musk'S", 'Elon Musk S'],
    'Donald Trump': ['Trump', 'Donald Trump'],
    'Joe Biden': ['Biden', 'Joe Biden'],
    'Sam Altman': ['Altman', 'Sam Altman'],
    'Narendra Modi': ['Modi', 'Narendra Modi'],
    'Kamala Harris': ['Harris', 'Kamala Harris'],
    'Rishi Sunak': ['Sunak', 'Rishi Sunak'],
    'Prince Harry': ['Harry', 'Prince Harry'],
    'Meghan Markle': ['Meghan', 'Meghan Markle'],
    'Satya Nadella': ['Nadella', 'Satya Nadella'],
    'Sundar Pichai': ['Pichai', 'Sundar Pichai'],
    'Mark Zuckerberg': ['Zuckerberg', 'Mark Zuckerberg'],
    'Jensen Huang': ['Huang', 'Jensen Huang', 'Jensen'],
    'Warren Buffett': ['Buffett', 'Warren Buffett'],
    'Jeff Bezos': ['Bezos', 'Jeff Bezos'],
    'Bill Gates': ['Gates', 'Bill Gates'],
    'Tim Cook': ['Cook', 'Tim Cook'],
    'Geoffrey Hinton': ['Hinton', 'Geoffrey Hinton'],
    'Xi Jinping': ['Xi', 'Xi Jinping'],
    'Barack Obama': ['Obama', 'Barack Obama'],
    'Taylor Swift': ['Taylor Swift', "Taylor Swift'S", 'Swift'],
    'Paul McCartney': ['Paul Mccartney', 'Mccartney', 'Paul'],
    'Scarlett Johansson': ['Scarlett Johansson', 'Johansson'],
    'Chuck Schumer': ['Schumer', 'Chuck Schumer'],
    'Ilya Sutskever': ['Sutskever', 'Ilya Sutskever'],
    'Greg Brockman': ['Greg Brockman', 'Brockman'],
    'Kate Middleton': ['Kate', 'Kate Middleton'],
    'Prince William': ['William', 'Prince William'],
    'Khloe Kardashian': ['Khloe Kardashian', 'Khloe'],
    'Kim Kardashian': ['Kim Kardashian', 'Kim'],
    'Kanye West': ['Kanye West', 'Ye']
}


# Consolidate the counts from original Counter
consolidated_people = {}
for canonical, aliases in alias_groups.items():
    total = sum(people.get(alias, 0) for alias in aliases)
    consolidated_people[canonical] = total

# Add back the rest of people not in any alias group
all_aliases = set(alias for aliases in alias_groups.values() for alias in aliases)
for name, count in people.items():
    if name not in all_aliases:
        consolidated_people[name] = count

# Convert back to Counter and show top 100
people_merged = Counter(consolidated_people)
print("\nTop People (Merged):\n", people_merged.most_common(100))
# Out:
# Top People (Merged):
#  [('Elon Musk', 45397), ('Sam Altman', 42933), ('Donald Trump', 38362), ('Joe Biden', 30502), ('Taylor Swift', 10943), ('Narendra Modi', 10050), ('Kamala Harris', 6366), ('Mark Zuckerberg', 6347), ('Satya Nadella', 6295), ('Rishi Sunak', 5806), ('Sundar Pichai', 5545), ('Prince Harry', 5452), ('Kim Kardashian', 5032), ('Jensen Huang', 4852), ('Meghan Markle', 4748), ('Putin', 4420), ('Paul McCartney', 4407), ('Bobby Allyn', 3960), ('Geoffrey Hinton', 3886), ('Bill Gates', 3843), ('Scarlett Johansson', 3677), ('Greg Brockman', 3516), ('Warren Buffett', 3506), ('Kate Middleton', 3497), ('Chuck Schumer', 3402), ('Bard', 3353), ('Xi Jinping', 3325), ('Charles', 3281), ("Matt O'Brien", 2811), ('Ilya Sutskever', 2750), ('Travis Kelce', 2701), ('David', 2612), ('Prince William', 2505), ('Metla Sudha Sekhar', 2450), ('Jennifer Lopez', 2410), ('Drake', 2275), ('Phil Mackintosh', 2147), ('Barbie', 2124), ('Tim Cook', 2040), ('Desantis', 1908), ('Ben Affleck', 1897), ('Kylie Jenner', 1847), ('Britney Spears', 1809), ('Shakespeare', 1719), ('My Quotes', 1628), ('Geoff Brumfiel', 1600), ('Mira Murati', 1598), ('Kanye West', 1574), ('Madonna', 1543), ('Netanyahu', 1538), ('Shear', 1478), ('Smith', 1438), ('Khan', 1418), ('Diddy', 1410), ('Kelvin Chan', 1403), ('Selena Gomez', 1400), ('Tupac', 1396), ('Khloe Kardashian', 1393), ('Katy Perry', 1391), ('Rihanna', 1389), ('John', 1380), ('Shannon Bond', 1353), ('Lemoine', 1328), ('Tom Brady', 1316), ('Tom Cruise', 1307), ('Jeff Bezos', 1289), ('Virat Kohli', 1287), ('Hailey Bieber', 1269), ('Emily Ratajkowski', 1262), ('Sam', 1260), ('John Larkin', 1260), ('Camilla', 1258), ('Francis', 1240), ('Barack Obama', 1228), ('Kendall Jenner', 1222), ('Beyonce', 1222), ('King', 1212), ('Victoria Beckham', 1201), ('Schwartz', 1201), ('Lee', 1187), ('Lennon', 1186), ('Vladimir Putin', 1183), ('Macron', 1179), ('Barchart', 1162), ('Chloe Veltman', 1153), ('Matthew Perry', 1134), ('Sarah Silverman', 1120), ('Richard Drew', 1110), ('Rita Ora', 1105), ('Imran Khan', 1096), ('Martin', 1077), ('Kourtney Kardashian', 1065), ('Michael Dwyer', 1059), ('Victor Teboul', 1047), ('Jim Love', 1043), ('Tom Gardner', 1034), ('Steve Inskeep', 1023), ('Taylor', 1021), ('Ai Weiwei', 1018), ('Ryan Reynolds', 1000)]

# %% [markdown]
# Group organizations

# %%
org_alias_groups = {
    'Google': ['Google', 'Google Play', 'Google Cloud'],
    'Microsoft': ['Microsoft', 'Windows'],
    'Meta': ['Meta', 'Facebook', 'Instagram'],
    'Amazon': ['Amazon', 'Aws'],
    'Nvidia': ['Nvidia'],
    'Apple': ['Apple'],
    'OpenAI': ['Openai', 'Chatgpt'],
    'IBM': ['Ibm'],
    'AMD': ['Amd'],
    'Intel': ['Intel'],
    'Tesla': ['Tesla'],
    'Netflix': ['Netflix'],
    'Samsung': ['Samsung'],
    'YouTube': ['Youtube'],
    'LinkedIn': ['Linkedin'],
    'Twitter': ['Twitter', 'X'],
    'CNBC': ['Cnbc'],
    'Reuters': ['Ap', 'The Associated Press', 'Associated Press'],
    'Nexstar': ['Nexstar', 'Nexstar Media Inc.'],
    'Nasdaq': ['Nasdaq', 'Nasdaq.Com', 'Nasdaq, Inc.'],
    'White House': ['White House', 'The White House'],
    'New York Times': ['The New York Times', 'Times'],
    'Digi Communications': ['Digi Communications N.V.', 'Digi Communications Nv']
}

# Merge organization names
merged_orgs = {}
for canonical, aliases in org_alias_groups.items():
    total = sum(orgs.get(alias, 0) for alias in aliases)
    merged_orgs[canonical] = total

# Add orgs not in any alias group
all_org_aliases = set(alias for aliases in org_alias_groups.values() for alias in aliases)
for name, count in orgs.items():
    if name not in all_org_aliases:
        merged_orgs[name] = count

# Final sorted result
merged_orgs_counter = Counter(merged_orgs)
print("\nTop Merged Organizations:\n", merged_orgs_counter.most_common(100))
# Out:
# Top Merged Organizations:
#  [('OpenAI', 221781), ('Google', 179615), ('Microsoft', 136731), ('Meta', 92358), ('Apple', 80942), ('Nvidia', 66114), ('Amazon', 64354), ('Lg', 46763), ('Reuters', 44767), ('Fcc', 40113), ('Samsung', 35254), ('YouTube', 33292), ('Nasdaq', 29920), ('LinkedIn', 28920), ('Twitter', 27050), ('Digi Communications N.V.', 20767), ('Intel', 17799), ('Nexstar', 17636), ('AMD', 17030), ('Eu', 16932), ('Tesla', 16597), ('IBM', 15404), ('Tiktok', 14682), ('Bing', 13649), ('Netflix', 13100), ('Menafn', 12726), ('Congress', 12685), ('Anthropic', 11958), ('Ein', 11634), ('Alphabet', 11010), ('CNBC', 10542), ('White House', 10113), ('Adobe', 9699), ('Getty Images', 9673), ('Fda', 9449), ('Nfl', 8620), ('Newsfeed', 8497), ('Reddit', 8453), ('Cna', 8136), ('Mint', 8057), ('Whatsapp', 7971), ('Deepseek', 7853), ('The Motley Fool', 7672), ('Bloomberg', 7669), ('Afp', 7582), ('Sony', 7281), ('Android', 7085), ('Salesforce', 6878), ('Dell', 6397), ('Sec', 6304), ('Fox', 6262), ('Oracle', 6245), ('Lenovo', 5883), ('Baidu', 5850), ('Cision', 5832), ('Pbs', 5813), ('Senate', 5798), ('Ftc', 5776), ('Huawei', 5762), ('Spotify', 5630), ('Nasa', 5542), ('Qualcomm', 5420), ('Un', 5416), ('Fed', 5233), ('Ein Presswire', 5226), ('Bard', 5146), ('Forbes', 5142), ('Nbc', 5142), ('Newsnation', 5118), ('Nba', 5079), ('Digi Communications Nv', 4978), ('Zdnet', 4959), ('Snapchat', 4907), ('Oneplus', 4893), ('Sap', 4731), ('Cbs', 4706), ('Asus', 4659), ('House', 4591), ('Future', 4584), ('Walmart', 4567), ('Oppo', 4529), ('Daily Mail', 4507), ('Disney', 4494), ('Xiaomi', 4493), ('Bt', 4322), ('Deepmind', 4320), ('Sports Illustrated', 4316), ('Smart Portfolio', 4196), ('Business Wire', 4099), ('Fbi', 4097), ('Bjp', 4090), ('Homeland Security', 4036), ('Scripps', 4007), ('Wvia', 3927), ('Hamas', 3901), ('Wlrn', 3892), ('Alibaba', 3848), ('The Hill', 3779), ('Tipranks', 3779), ('Mailonline', 3745)]

# %% [markdown]
# Group technology

# %%
tech_alias_groups = {
    'ChatGPT': ['Chatgpt', 'Chat Gpt', 'Chatgpt Plus', 'Chatgpt Enterprise', 'Chatgpt Pro',
                'Chatgpt 4', 'Chatgpt-4', 'Chatgpt Ai', 'Chatgpt Search', 'Chatgpt 4O',
                'Gpt', 'Gptzero', 'Gpts', 'Gptzero', 'Gpt-3', 'Gpt 3.5', 'Gpt-4', 'Gpt-4 Turbo', 'Gpt4', 'Gpt-4O', 'Gpt-4O Mini'],
    'AI Pin': ['Ai Pin', 'The Ai Pin', 'The Humane Ai Pin'],
    'Google Cloud': ['Google Cloud', 'Google Cloud S'],
    'OpenAI': ['Openai', 'Azure Openai', 'Azure Openai Service'],
    'Bard': ['Bard', 'Google Bard', 'Bard Ai'],
    'LLaMA': ['Llama', 'Llama 2', 'Llama 3'],
    'Generative AI': ['Generative Ai', 'Genai', 'Gen Ai', 'Artificial Intelligence', 'Ai'],
    'Meta AI': ['Meta Ai'],
    'Copilot': ['Copilot Ai', 'Copilot'],
    'Stability AI': ['Stability Ai'],
    'Mistral AI': ['Mistral Ai'],
    'Palm AI': ['Palm Ai'],
    'Vertex AI': ['Vertex Ai'],
    'Gemini AI': ['Gemini Ai'],
    'Soundhound AI': ['Soundhound Ai'],
    'Grok AI': ['Grok Ai', 'Grok Chatbot'],
    'Duet AI': ['Duet Ai'],
    'TruthGPT': ['Truthgpt'],
    'Arbdoge AI': ['Arbdoge Ai'],
    'Thinq AI': ['Thinq Ai', 'Ai Thinq'],
    'LangChain': ['Langchain'],
    'Apache Spark': ['Spark', 'Apache Spark'],
    'Smart Devices': ['Smartwatch', 'Smart Tv', 'Smart Home', 'Smart Thermostat'],
    'Voice Assistants': ['Clear Voice Pro']
}

normalized_tech = Counter()
for tech, count in techs.items():
    normalized_key = tech.strip().lower().title()
    normalized_tech[normalized_key] += count

# normalize group
normalized_alias_groups = {
    canonical: [alias.strip().lower().title() for alias in aliases]
    for canonical, aliases in tech_alias_groups.items()
}

# count
merged_tech = {}
for canonical, aliases in normalized_alias_groups.items():
    total = sum(normalized_tech.get(alias, 0) for alias in aliases)
    merged_tech[canonical] = total

# Add tech not in any alias group
all_aliases = set(alias for aliases in normalized_alias_groups.values() for alias in aliases)
for tech, count in normalized_tech.items():
    if tech not in all_aliases:
        merged_tech[tech] = count

# Final sorted result
merged_tech_counter = Counter(merged_tech)
print("\nTop Merged Technologies:\n", merged_tech_counter.most_common(100))
# Out:
# Top Merged Technologies:
#  [('ChatGPT', 135871), ('Bard', 14324), ('Generative AI', 6217), ('OpenAI', 3896), ('LLaMA', 3524), ('Ultragear', 2660), ('Meta AI', 2448), ('Galaxy Ai', 2111), ('Gmail', 1863), ('Vision Pro', 1624), ('Metaverse', 1548), ('Smart Devices', 1471), ('Safari', 1325), ('Airpods', 1277), ('Apple Vision Pro', 1258), ('AI Pin', 1074), ('Node Ai', 1043), ('Thinq AI', 1022), ('Arbdoge AI', 981), ('Search', 972), ('Gemini AI', 958), ('Sleepless Ai', 919), ('Vertex AI', 879), ('Quantum Ai', 861), ('Google Cloud', 860), ('Macbook Air', 837), ('Barchart', 819), ('Grok AI', 798), ('My Ai', 750), ('Cybertruck', 726), ('Java', 726), ('Apache Spark', 723), ('Stargate', 723), ('Paal Ai', 663), ('Palm AI', 609), ('Ipad Air', 587), ('Lunar Lake', 569), ('Searchgpt', 560), ('Arm', 552), ('Stability AI', 548), ('Duet AI', 519), ('Tech Radar Pro', 517), ('Ai Dd', 511), ('Xai', 481), ('Edge Ai', 475), ('Starlink', 442), ('Lightchain Ai', 437), ('Conversational Ai', 434), ('Dolby Vision', 425), ('Soundbars', 406), ('Webcatalog Desktoplearn', 376), ('Clickup Ai', 374), ('Starship', 369), ('Grammarly', 360), ('Copilot', 353), ('Paint', 346), ('TruthGPT', 338), ('Aria', 337), ('Mistral AI', 318), ('Soundhound AI', 314), ('Ai Sound Pro', 313), ('Transformer', 312), ('Circle To Search', 311), ('Soundbar', 307), ('Chrome Safari', 302), ('Cardano', 299), ('The Vision Pro', 288), ('Airpods Pro', 287), ('Ai Studio', 286), ('Trainium', 285), ('Chatbot', 281), ('Smartsheetlearnblogsoftware', 273), ('Arc', 264), ('Link Machine Learning', 254), ('Dgx Cloud', 252), ('LangChain', 251), ('Wear Os', 250), ('Matrix Ai Network', 249), ('Auto-Gpt', 249), ('Lava', 247), ('Deep Research', 237), ('Airplay', 235), ('Voice Assistants', 233), ('Quantum', 233), ('Digital Mark', 233), ('Garena Free Fire Max', 226), ('Model 3', 225), ('Terarecon', 225), ('Bing Ai', 225), ('Generative Pre-Trained Transformer', 224), ('Agentic Ai', 224), ('Claude Ai', 223), ('Bard Advanced', 218), ('Clickup Brain Chat Agents', 218), ('Einstein Gpt', 216), ('Tecno Spark Go', 216), ('Air Force One', 214), ('The Apple Vision Pro', 214), ('Warid', 213), ('Gpt-3.5 Turbo', 213)]

# %% [markdown]
# Group locations

# %%
location_alias_groups = {
    'United States': [
        'Us', 'U.S.', 'The United States', 'America', 'Usa',
        'New York', 'Nyc', 'California', 'San Francisco', 'Texas', 'Florida', 'Washington', 'Illinois',
        'Colorado', 'Ohio', 'Pennsylvania', 'Michigan', 'Utah', 'Oklahoma', 'Connecticut', 'New Mexico',
        'Arizona', 'Arkansas', 'Idaho', 'Iowa', 'Minnesota', 'Missouri', 'Indiana', 'North Carolina',
        'Massachusetts', 'Hawaii', 'Tennessee', 'Oregon', 'New Jersey', 'Wisconsin', 'Louisiana',
        'Montana', 'Kansas', 'New Hampshire', 'Alabama', 'Delaware', 'Virginia', 'Maryland',
        'Kentucky', 'South Carolina', 'West Virginia', 'Nevada', 'Mississippi', 'Alaska',
        'North Dakota', 'South Dakota', 'Nebraska', 'Las Vegas', 'Chicago', 'Los Angeles'
    ],
    'United Kingdom': ['Uk', 'United Kingdom', 'London'],
    'Russia': ['Russia'],
    'China': ['China'],
    'India': ['India', 'Delhi', 'Mumbai'],
    'Canada': ['Canada'],
    'Australia': ['Australia'],
    'Germany': ['Germany'],
    'France': ['France'],
    'Japan': ['Japan'],
    'South Korea': ['South Korea'],
    'Middle East': ['Middle East', 'Saudi Arabia', 'Uae', 'Qatar', 'Kuwait', 'Oman', 'Bahrain', 'Jordan'],
    'Israel': ['Israel'],
    'Ukraine': ['Ukraine'],
    'Brazil': ['Brazil'],
    'Mexico': ['Mexico'],
    'North America': ['North America'],
    'Europe': ['Europe'],
    'Asia': ['Asia'],
    'Taiwan': ['Taiwan'],
    'Hong Kong': ['Hong Kong'],
    'Africa': ['South Africa', 'Kenya', 'Morocco', 'Algeria', 'Tunisia'],
}

# Normalize original locations dictionary
normalized_locations = Counter()
for loc, count in locations.items():
    normalized_locations[loc.strip().lower().title()] += count

# Normalize alias group mappings
normalized_alias_groups = {
    canonical: [alias.strip().lower().title() for alias in aliases]
    for canonical, aliases in location_alias_groups.items()
}

# Merge location counts based on alias groups
merged_locations = {}
for canonical, aliases in normalized_alias_groups.items():
    total = sum(normalized_locations.get(alias, 0) for alias in aliases)
    merged_locations[canonical] = total

# Add any locations not captured in alias groups
all_aliases = set(alias for aliases in normalized_alias_groups.values() for alias in aliases)
for loc, count in normalized_locations.items():
    if loc not in all_aliases:
        merged_locations[loc] = count

# Display result
merged_locations_counter = Counter(merged_locations)
print("\nTop Merged Locations:\n", merged_locations_counter.most_common(30))
# Out:
# Top Merged Locations:
#  [('India', 128892), ('Middle East', 116765), ('United Kingdom', 82948), ('China', 71526), ('Canada', 35509), ('Europe', 32864), ('Russia', 26779), ('United States', 26465), ('Ukraine', 26311), ('Australia', 25630), ('Israel', 25444), ('France', 23751), ('Japan', 22038), ('Germany', 20593), ('Italy', 18055), ('Singapore', 17860), ('Pakistan', 17625), ('Spain', 16429), ('Lebanon', 16205), ('Georgia', 16183), ('Egypt', 13644), ('Brazil', 13618), ('Maine', 13265), ('Indonesia', 13244), ('Taiwan', 13235), ('Hollywood', 13171), ('Mexico', 13026), ('Portugal', 12793), ('Malaysia', 12579), ('Asia', 12505)]

# %%
# --- STEP 1: Normalize the original locations ---
normalized_locations = Counter()
for loc, count in locations.items():
    normalized_loc = loc.strip().lower().title()
    normalized_locations[normalized_loc] += count

# --- STEP 2: Define alias groups (normalized as well) ---
location_alias_groups = {
    'United States': [
        'Us', 'U.S.', 'The United States', 'America', 'Usa',
        'New York', 'Nyc', 'California', 'San Francisco', 'Texas', 'Florida', 'Washington', 'Illinois',
        'Colorado', 'Ohio', 'Pennsylvania', 'Michigan', 'Utah', 'Oklahoma', 'Connecticut', 'New Mexico',
        'Arizona', 'Arkansas', 'Idaho', 'Iowa', 'Minnesota', 'Missouri', 'Indiana', 'North Carolina',
        'Massachusetts', 'Hawaii', 'Tennessee', 'Oregon', 'New Jersey', 'Wisconsin', 'Louisiana',
        'Montana', 'Kansas', 'New Hampshire', 'Alabama', 'Delaware', 'Virginia', 'Maryland',
        'Kentucky', 'South Carolina', 'West Virginia', 'Nevada', 'Mississippi', 'Alaska',
        'North Dakota', 'South Dakota', 'Nebraska', 'Las Vegas', 'Chicago', 'Los Angeles'
    ],
    'United Kingdom': ['Uk', 'United Kingdom', 'London'],
    'Russia': ['Russia'],
    'China': ['China'],
    'India': ['India', 'Delhi', 'Mumbai'],
    'Canada': ['Canada'],
    'Australia': ['Australia'],
    'Germany': ['Germany'],
    'France': ['France'],
    'Japan': ['Japan'],
    'South Korea': ['South Korea'],
    'Middle East': ['Middle East', 'Saudi Arabia', 'Uae', 'Qatar', 'Kuwait', 'Oman', 'Bahrain', 'Jordan'],
    'Israel': ['Israel'],
    'Ukraine': ['Ukraine'],
    'Brazil': ['Brazil'],
    'Mexico': ['Mexico'],
    'North America': ['North America'],
    'Europe': ['Europe'],
    'Asia': ['Asia'],
    'Taiwan': ['Taiwan'],
    'Hong Kong': ['Hong Kong'],
    'Africa': ['South Africa', 'Kenya', 'Morocco', 'Algeria', 'Tunisia'],
}

# Normalize the alias group entries
normalized_alias_groups = {
    canonical: [alias.strip().lower().title() for alias in aliases]
    for canonical, aliases in location_alias_groups.items()
}

# --- STEP 3: Merge counts by alias ---
merged_locations = {}
for canonical, aliases in normalized_alias_groups.items():
    total = sum(normalized_locations.get(alias, 0) for alias in aliases)
    merged_locations[canonical] = total

# --- STEP 4: Add locations not in any alias group ---
all_aliases = set(alias for aliases in normalized_alias_groups.values() for alias in aliases)
for loc, count in normalized_locations.items():
    if loc not in all_aliases:
        merged_locations[loc] = count

# --- STEP 5: Print result ---
merged_locations_counter = Counter(merged_locations)
print("\nTop Merged Locations:\n", merged_locations_counter.most_common(30))
# Out:
# Top Merged Locations:
#  [('India', 128892), ('Middle East', 116765), ('United Kingdom', 82948), ('China', 71526), ('Canada', 35509), ('Europe', 32864), ('Russia', 26779), ('United States', 26465), ('Ukraine', 26311), ('Australia', 25630), ('Israel', 25444), ('France', 23751), ('Japan', 22038), ('Germany', 20593), ('Italy', 18055), ('Singapore', 17860), ('Pakistan', 17625), ('Spain', 16429), ('Lebanon', 16205), ('Georgia', 16183), ('Egypt', 13644), ('Brazil', 13618), ('Maine', 13265), ('Indonesia', 13244), ('Taiwan', 13235), ('Hollywood', 13171), ('Mexico', 13026), ('Portugal', 12793), ('Malaysia', 12579), ('Asia', 12505)]
